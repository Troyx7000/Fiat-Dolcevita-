# %% [markdown]
# # Scraping Text Data from Fiat Forums

# %%
# !pip install bs4
# Out:
# Collecting bs4
#   Downloading bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Collecting beautifulsoup4 (from bs4)
#   Downloading beautifulsoup4-4.12.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting soupsieve>1.2 (from beautifulsoup4->bs4)
#   Downloading soupsieve-2.5-py3-none-any.whl.metadata (4.7 kB)
# Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Downloading beautifulsoup4-4.12.3-py3-none-any.whl (147 kB)
#    ---------------------------------------- 0.0/147.9 kB ? eta -:--:--
#    ---------- ---------------------------- 41.0/147.9 kB 991.0 kB/s eta 0:00:01
#    ---------------------------------------- 147.9/147.9 kB 2.9 MB/s eta 0:00:00
# Downloading soupsieve-2.5-py3-none-any.whl (36 kB)
# Installing collected packages: soupsieve, beautifulsoup4, bs4
# Successfully installed beautifulsoup4-4.12.3 bs4-0.0.2 soupsieve-2.5
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: C:\Users\zekai\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# This code scrapes forum posts and comments from the Fiat Forum, starting from a specific search results page. It navigates through multiple pages, extracting the title, content, comments, and comment timestamps from each post. The extracted data is saved into a CSV file. The scraping process is limited to a maximum of 50 pages.

# %%
import requests
from bs4 import BeautifulSoup
import csv

# Forum search results homepage URL
base_url = "https://www.fiatforum.com"
search_url = "/search/887488/?q=fiat+500+uk&o=relevance"

# Set request headers
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

# Initial page URL
current_url = base_url + search_url

# Create a CSV file and save it to the specified path
file_path = 'E:/ARP/forum_data_50_pages.csv'
with open(file_path, mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(["Title", "Content", "Comment", "Comment Time"])

    # Limit the number of pages to scrape
    max_pages = 50
    current_page = 1

    while current_url and current_page <= max_pages:
        print(f"Processing page URL: {current_url}")
        response = requests.get(current_url, headers=headers)
        print(f"Page response status code: {response.status_code}")
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find all post links
        post_links = soup.find_all("a", href=True)
        post_links = [link for link in post_links if '/threads/' in link['href'] and 'title' not in link['href']]

        if not post_links:
            print("No post links found.")
            break
        
        print("Found post links:")
        for link in post_links:
            post_url = link.get('href')
            full_post_url = base_url + post_url if post_url.startswith('/') else post_url
            print(f"Processing post URL: {full_post_url}")
            post_response = requests.get(full_post_url, headers=headers)
            print(f"Post page response status code: {post_response.status_code}")
            post_soup = BeautifulSoup(post_response.text, 'html.parser')

            # Extract post title
            title_tag = post_soup.find("h1", class_="p-title-value")
            title = title_tag.get_text().strip() if title_tag else "No title"
            print(f"Title: {title}")

            # Extract post content
            content_tag = post_soup.find("div", class_="bbWrapper")
            content = content_tag.get_text().strip() if content_tag else "No content"
            print(f"Content: {content}")

            # Extract comments and timestamps
            comments = post_soup.find_all("div", class_="bbWrapper")
            time_tags = post_soup.find_all("time", class_="u-dt")
            for comment, time_tag in zip(comments, time_tags):
                comment_text = comment.get_text().strip()
                comment_time = time_tag.get('datetime', 'No time')
                if comment_text:
                    writer.writerow([title, content, comment_text, comment_time])

        # Find the next page link
        next_page = soup.find("a", class_="pageNav-jump pageNav-jump--next")
        if next_page:
            current_url = base_url + next_page.get('href')
            current_page += 1
        else:
            current_url = None

print("Scraping complete.")
# Out:
# Processing page URL: https://www.fiatforum.com/search/887488/?q=fiat+500+uk&o=relevance
# Page response status code: 200
# Found post links:
# Processing post URL: https://www.fiatforum.com/threads/new-fiat-500-confused-from-uk.508139/
# Post page response status code: 200
# Title: General New Fiat 500! Confused from UK!
# Content: I have just leased a new Fiat 500 hybrid. The manual is pants! Going to need help - TIA
# Processing post URL: https://www.fiatforum.com/threads/window-switch-wiring-on-uk-fiat-500-s3.500202/
# Post page response status code: 200
# Title: Technical window switch wiring on UK fiat 500 S3
# Content: Hello all,
#
# I'm in the process of adding a UK spec. Biposto shifter and lower carbon dash to a US Spec. North American Fiat 500 Abarth.
#
# The Biposto kit uses the older S3 switch gear out of a Fiat 500 for the UK. and I'm trying to determine what wire on the switch does what? I think the easiest thing would be to decode an S3 switch, or the window wiring out of a UK based S4. The prior owner had the switches hooked to an UK S4 car, and prior to sending them to me, he labeled each wire with the color coding of his car. Unfortunately none of the color codes match the US spec car, or anything I've been sent for a UK spec Fiat 500? I've also pulled Ebay images from UK based Fiat 500 switches, and the color of the wires seem to match what the seller had labeled, but not what would make since with typical color coding on 12V systems??
#
# Any help would be appreciated!
#
# If I can determine what each color is for on the S3 switch, I think I can get it back together...
#
# Thanks so much!
#
# Brian
# Processing post URL: https://www.fiatforum.com/threads/2014-fiat-500-sport-1-2-manifold.502598/
# Post page response status code: 200
# Title: General 2014 fiat 500 sport 1.2 manifold
# Content: Hi all, I'm new to fiat 500's, fantastic cars, I have a 500 1.2 sport 2014, I'm looking for a new manifold, preferably stainless, however all the stainless ones I'm finding in the uk are for fitment 2007-2013. Does anyone know if there are any stainless manifolds with a 200 cell cat made for a 2014 fiat 500 sport 1.2.
# Thank you
# Processing post URL: https://www.fiatforum.com/threads/500-c-2016-uk-model.504341/
# Post page response status code: 200
# Title: Technical 500 c 2016 uk model
# Content: Hi all, my wife’s car has two problems. Fiat 500c 2016..
#
# 1) it says the boot is open all the time when it’s is physically closed.. the boot release works where the number plate light is, so believe the wiring loom is ok.. does the lock mechanism have a sensor within it?
#
# 2) her telephone connects to the car and she can hear people, but they cannot hear her. It’s not her phone as have tried another one, and I checked the voice commands using the steering wheel button and the car rewinds.. any ideas please?
# Processing post URL: https://www.fiatforum.com/threads/fiat-500-digital-speedo.497170/
# Post page response status code: 200
# Title: Technical Fiat 500 digital speedo
# Content: Does anyone no how to turn on the additional digital speedo on a 2019 fiat 500 uk model
# Processing post URL: https://www.fiatforum.com/threads/calling-all-uk-owners-of-fiat-500-1-2ltr-petrol-cars-2018-or-newer.499917/
# Post page response status code: 200
# Title: General Calling all UK owners of Fiat 500 1.2ltr petrol cars 2018 or newer
# Content: Me again,
# My last post had a bit of a weird title and on viewing it, it didn't seem as if most people would look at it so I have posted again with this title.
# If you have a UK Fiat 500 1.2 petrol car 2018 or newer please read this post:
# Bracket fixing front suspension crossmember to bodyshell.​Thanks
# Processing post URL: https://www.fiatforum.com/threads/any-uk-male-fiat-500-owners.493025/
# Post page response status code: 200
# Title: General Any UK male Fiat 500 owners?
# Content: I’m potentially buying a Fiat 500, but worried I’m buying a girls car.  I know it’s stereotypically a female car, all the YouTube reviews are women trying to work out what the buttons on the dashboard do lol.
# Are there any UK male owners? What got you over the stigma? Lol
# Processing post URL: https://www.fiatforum.com/threads/2008-fiat-500-gearbox-leak.505053/
# Post page response status code: 200
# Title: Technical 2008 Fiat 500 gearbox leak
# Content: Hello, I'm posting on behalf of a friend in the Channel Islands. She has a 2008 Fiat 500 1.2L which has done about 70,000 miles. Due to being on a small island with max speed 35mph, most journeys are very short and I wonder whether this causes more wear and tear than longer journeys in the UK?
#
# The clutch was replaced about 2 months ago. Recently she has said there is a whirring noise. A couple of days ago, she found oil under the car. It has gone to a garage who say it is a gearbox fault but I don't have any more details than that! The garage said it would cost £1500 in labour but I'm not exactly sure what they are planning to do. It might not be economical to spend that much on a car of that age.
#
# Sorry I can't be more helpful, I will try and find out more. Are gearbox problems common in a Fiat 500 of this age and mileage? Is it likely to be related to changing the clutch?
# Processing post URL: https://www.fiatforum.com/threads/fiat-500-2017-1-2-uk-workshop-manual-technical-data-wanted.508657/
# Post page response status code: 200
# Title: Technical Fiat 500 2017 1.2 - UK workshop manual / technical data wanted
# Content: Hi folks,
#
# Does anyone have this manual? I've found an Italian one on the forum but not the English one. I know I could translate parts of it but that's hard work.
#
# I don't mind paying for it.
#
# Must be for the 2017 1.2 petrol model. I have the manual for up to what I think is 2012.
# Processing post URL: https://www.fiatforum.com/threads/newbie-from-buckinghamshire-uk.499516/
# Post page response status code: 200
# Title: Newbie from Buckinghamshire, UK
# Content: Hello all. I'm new to the forum. Looking forward to sharing and receiving advice on the Fiat 500 Twinair.
# Processing post URL: https://www.fiatforum.com/threads/for-sale-classic-fiat-500-f-rhd-professional-restore.499790/
# Post page response status code: 200
# Title: 500 (For Sale) Classic Fiat 500 F RHD professional restore
# Content: Psst! Are you free on August the 3rd?  We've got a brand new event called FIATs and Friends to attend.  Held at the rather fantastic British Motor Museum (ticket includes entry) in a pretty central location, there will be loads to see and do so there's no excuse not to be there 😜  Sign up using the link above to register yourself for our stand and save £5 on entry - everyone is welcome!
# Processing post URL: https://www.fiatforum.com/threads/help-2019-fiat-500-dualogic.501040/
# Post page response status code: 200
# Title: General HELP!! 2019 Fiat 500 Dualogic
# Content: Hi everyone, I’m from the UK.
# I’m collecting my 69 plate Fiat on Tuesday. It has the semi-auto Dualogic gearbox. I currently drive a 2009 semi-auto Kia picanto. The Fiat doesn’t have a “P” for park. The dealership I’m buying it from (not specialising in Fiat) have instructed me to park the car in “N” - neutral. Looking online I have found conflicting information, some people say “N” is correct whilst others say park in gear “A/M” if parked flat or uphill and park in “R” if downhill. I would like to know correct procedure as I definitely don’t want to cause damage to my lovely new car.
# Thanks in advance for any responses.
# Molly
# Processing post URL: https://www.fiatforum.com/threads/help-2019-fiat-500-dualogic.501039/
# Post page response status code: 200
# Title: HELP!! 2019 Fiat 500 Dualogic
# Content: Hi everyone, I’m from the UK.
# I’m collecting my 69 plate Fiat on Tuesday. It has the semi-auto Dualogic gearbox. I currently drive a 2009 semi-auto Kia picanto. The Fiat doesn’t have a “P” for park. The dealership I’m buying it from (not specialising in Fiat) have instructed me to park the car in “N” - neutral. Looking online I have found conflicting information, some people say “N” is correct whilst others say park in gear “A/M” if parked flat or uphill and park in “R” if downhill. I would like to know correct procedure as I definitely don’t want to cause damage to my lovely new car.
# Thanks in advance for any responses.
# Molly
# Processing post URL: https://www.fiatforum.com/threads/what-looks-like-a-500-but-is-neither-a-500-nor-a-500.501838/
# Post page response status code: 200
# Title: General What looks like a 500 but is neither a 500 nor a 500?
# Content: It seems that Fiat want a light quadricycle of their own, or quite like the Citroen Ami but think it's ugly. Either way, it looks a bit 500ish.
#
#
#
#
#
#
#
#
#
# 2024 Fiat Topolino to launch in UK as Citroen Ami twin | Autocar
#
#
# Italian micro-EV will target Gen Z buyers with low price; can be optioned without a roof or doors
#
#
#
#
# www.autocar.co.uk
# Processing post URL: https://www.fiatforum.com/threads/fiat-500-led-conversion-uk-based-newbie.489669/
# Post page response status code: 200
# Title: General Fiat 500 LED conversion UK based newbie
# Content: Hello everyone!
#
# New owner of a used 500 in the UK and delighted with the car (minus a few things that will hopefully sort out soon).
#
# I was hoping to get some help with the front headlights as I’m thinking of replacing them with LEDs to improve visibility (also like the look).
#
# Has anyone tried to replace them themselves with budget friendly Amazon/EBay (sub £50) options?
#
# Looking forward to your insight
#
# Tee
# Processing post URL: https://www.fiatforum.com/threads/is-this-head-salvageable.508961/post-4754020
# Post page response status code: 200
# Title: Technical Is this head salvageable?
# Content: Hi!
# I bought a 650cc engine with some bits missing on the cheap in order to convert it to a semi-hot 695cc. Basically I only wanted to use the crank case, crankshaft and cylinder head as the rest of it is getting replaced anyway.
#
# When I took of the head I was greeted with this (see attached photo)... Well, I now know why the engine had bits missing!
#
#
# I have a couple of questions:
#
# WTH happened here? I've seen faulty head gaskets before, but never this kind of carnage... And I suspect that not all damage (of any!) is caused by a leaking head gasket, there is evidence of mechanical damage too, almost as someone was trying to grind away material with an angle grinder. But why?
# Is this head salvageable, or would I be better off getting a new head? The plan was to skim the head, get bigger valves and smooth out the ports so extensive work is going to be done on the head anyway, no matter if I buy a "new" one or not. But I am curious as to what you think: is this damage repairable?
# Processing post URL: https://www.fiatforum.com/threads/new-member-at-bottom-of-uk.502970/
# Post page response status code: 200
# Title: new member at bottom of uk!
# Content: Hi all.
# Having searched and used this forum for many years I have finally signed up. Current fiat is a 2019 tipo easy plus which I've had from new and am really pleased with the car, the aftercare,not so much!.
# Previous to the tipo we had a 500 lounge (2015 in coral) which was a truly amazing little car.
# Before that, a 2013 punto which met an early demise at the hands (branches?) of an oak tree that fell on it! totally destroyed the car which was travelling at abou40mph at the time, but driver and passenger both walked away. amazing.
# Processing post URL: https://www.fiatforum.com/threads/fiat-uk-is-looking-for-fiat-500-owners-win-lb500-shopping-vouchers.452085/
# Post page response status code: 200
# Title: General Fiat UK is looking for FIAT 500 owners! WIN £500 shopping vouchers
# Content: Fiat UK is calling for all Fiat 500 owners! You'll get to WIN a £500 shopping spree to celebrate the Fiat 500's six decades of style on the street! For your chance to win this week, they want to see pics of the Fiat 500 in cool urban environments... Got a pic of yours? Post it as a comment on the first post appearing on their Facebook page. Type in "Fiat GB" or "Fiat UK" to find their official page on Facebook.
#
# Good luck!
# Processing post URL: https://www.fiatforum.com/threads/first-ever-fiat.506620/
# Post page response status code: 200
# Title: First ever Fiat
# Content: I thought I would just say hi and make myself known.
#
# I’m in the UK and have just bought my daughter her first car. It’s a 2011 Fiat 500 Lounge and it reminds me of my younger days when I was driving around in a mini (not the BMW).
#
# I hope to do most of the future repairs and upkeep myself. I have a trusty Haynes manual and of course YouTube and forums like this to help.
#
# First job for me is the timing belt. I’ve never done one before but I’ll have a go. Just waiting for the parts to arrive.
#
# The forum has already been helpful. I thought I was missing a hose or something from my radiator. A quick search on here and I was able to establish that it is a mounting point and not something that should have a hose attached.
#
# Regards, Jerry.
# Processing page URL: https://www.fiatforum.com/search/887488/?page=2&q=fiat+500+uk&o=relevance
# Page response status code: 200
# Found post links:
# Processing post URL: https://www.fiatforum.com/threads/fiat-500-uk-tv-ad.128561/
# Post page response status code: 200
# Title: General Fiat 500 UK TV Ad
# Content: http://www.visit4info.com//advert/Fiat-500-Masterpieces-Fiat-500/54475
#
# Excellent campaign I think..
# Processing post URL: https://www.fiatforum.com/threads/installation-uconnect-7-to-us-version-fiat-500-abarth.493377/
# Post page response status code: 200
# Title: General Installation uconnect 7 to US version fiat 500 abarth
# Content: Hi guys, is there any chance to buy europe (or UK) uconnect 7 vp2 monitor and install to US version fiat 500 abarth 2017?
# Processing post URL: https://www.fiatforum.com/threads/right-place.505193/post-4718940
# Post page response status code: 200
# Title: General Right Place?
# Content: I'm not sure if I'm on the right forum. I am looking for 500e owners but I believe this is a UK forum and you don't have the same model as we have in the States. I have a 2016 1st gen. and we won't get the 2nd gen. EV until late 2024. Do you have any 1st gen cars over there?
#
# Noobi
# Processing post URL: https://www.fiatforum.com/threads/do-fiat-uk-stock-500s.152380/
# Post page response status code: 200
# Title: General Do Fiat UK stock 500's?
# Content: Still looking for a new car. Do Fiat UK stock 500's? I want a basic 1.2 Lounge spec with no options. Would it have to be a factory order? It is just that I don't want to wait 2 or 3 months for it.
#
# Thanks.
# Processing post URL: https://www.fiatforum.com/threads/hardback-book-on-500-from-fiat-uk.127144/
# Post page response status code: 200
# Title: General Hardback book on 500 from Fiat UK
# Content: I received a very nice and very thick hardback book on the 500 from Fiat UK today in the post and wrapped up in Xmas wrapping paper which was a nice touch. It has a card with it saying "Thank you for ordering your new Fiat 500, we hope you will enjoy the enclosed whilst we are building your car for you. Best wishes from Fiat UK". It's very good quality with lots of photo's of the original 500, info on the development of both cars and loads of photo's and design sketches showing how the new model took shape from the design stage, through the Trepiuno concept to the final production version. Has anyone else received their copy?
# Processing post URL: https://www.fiatforum.com/threads/need-help-understanding-the-difference-between-fiat-500-pop-and-fiat-500-lounge.486138/
# Post page response status code: 200
# Title: General Need help understanding the difference between Fiat 500 Pop and Fiat 500 Lounge
# Content: I'm looking into buying my (used) first car and I don't know a lot about fiat 500's(UK) Preferably looking at Fiat 500 2012-2014. I'm not sure between these 500's
#
# Fiat 500 Lounge 2013 Lounge 1.2 and Fiat 500 2013 Pop
#
# They look the same but what's the general difference between Pop and Lounge?
#
# And also what's the difference between Lounge and Cult?
#
# Many thanks
# Processing post URL: https://www.fiatforum.com/threads/smoked-rear-lights-for-fiat-500-c-2013-1-2.493614/
# Post page response status code: 200
# Title: General Smoked rear lights for fiat 500 c 2013 1.2.
# Content: Hi, does anyone know please if/where I can buy black/smoked rear lights for my fiat 500. Have seen some on ebay but there's a caveat at the bottom says they wouldn't fit the UK version with the fog lamp on the other side. Is it anything that's available in the UK?
# Processing post URL: https://www.fiatforum.com/threads/fiat-500-dualogic-error.498790/
# Post page response status code: 200
# Title: Technical Fiat 500 dualogic error
# Content: Hi everyone,
# While driving my Fiat 500 0.9 TwinAir semi-automatic on a busy road, I suddenly received a warning on the dashboard that read "Check transmission see handbook." As a result, I lost engine power and was unable to engage any gear. I ended up having to stop in the middle of the road. Despite trying to turn the car off and on again, the error message continued to display (similar to what happened in this video attached below).
#
# After a few more attempts, the car finally started working again, but the experience was quite scary. Has anyone else experienced a similar issue? After doing some research in this forum, it seems that a low level of transmission fluid could be the cause of the problem, but not sure. it was a damp road, I was wondering if could be some electronic issue ?
#
# Anyone has any suggestion ?
#
# I am from north London UK if anyone know a good FIAT specialist in London that can look into this dualogic system ?
#
# Thank you.
# Processing post URL: https://www.fiatforum.com/threads/what-is-the-difference-between-fiat-500-abarth-engine-and-the-500x-1-4-multi-engine.509115/post-4752569
# Post page response status code: 200
# Title: What is the difference between Fiat 500 abarth engine and the 500x 1.4 multi engine
# Content: Is there any difference between a Fiat 500 abarth engine and Fiat 500x 1.4 multiair engine as they look basically the same
# Processing post URL: https://www.fiatforum.com/threads/fiat-500-convertible.169032/
# Post page response status code: 200
# Title: General Fiat 500 Convertible
# Content: Three lines tucked away at the bottom of a letter sent out by Fiat to the dealer network yesterday...
#
#
#
#
# Fiat 500 Convertible
# The Fiat 500 Convertible will hit the UK market in April 2009
# The UK will be the second market to launch it, together with Italy
# From April 2009 we anticipate the Fiat 500 Convertible will grow to represent around 18% of the total Fiat 500 UK volumes
#
# Click to expand...
# Processing post URL: https://www.fiatforum.com/threads/fiat-500d-1964-history-paperwork-stockist-how-to-find-history-information-images.502909/
# Post page response status code: 200
# Title: General Fiat 500D 1964 - History - Paperwork - Stockist - How to find history information images?
# Content: Hi All
#
# Im looking for clues or if anyone has information about a fiat 500D 1964D light blue RHD or how to go about obtaining history etc. Ive filled out a v888 document has anyone had any luck with this? The only indication i have is that the car came from Taylor & Hales (woodgate) in farnham common. The car is a UK RHD
#
# Any ideas would be appreciated as to how others have been successful in obtaining information?
# Processing post URL: https://www.fiatforum.com/threads/confusing-500-fiat-uk-ad.451853/
# Post page response status code: 200
# Title: Technical confusing 500 FIAT UK ad..??
# Content: www.fiat.co.uk/fiat-500-range/500-anniversario
#
# only the 1242cc engine.. ok -sign of the times maybe..
#
# listed figures for both manual and semi-auto
#
# the manual uses less fuel .. but has higher emissions:chin:
#
#
#
# EDIT - my mistake.. having re-read it ..
#
# they had pointlessly put L/ 100 kms against the MPG figure..
#
# so I'd read it as bigger number = more consumption:bang:
# Processing post URL: https://www.fiatforum.com/threads/right-place.505193/post-4718837
# Post page response status code: 200
# Title: General Right Place?
# Content: I'm not sure if I'm on the right forum. I am looking for 500e owners but I believe this is a UK forum and you don't have the same model as we have in the States. I have a 2016 1st gen. and we won't get the 2nd gen. EV until late 2024. Do you have any 1st gen cars over there?
#
# Noobi
# Processing post URL: https://www.fiatforum.com/threads/new-fiat-500-owners-club-in-uk.193780/
# Post page response status code: 200
# Title: General New Fiat 500 Owner's Club in UK
# Content: I have a Mazda MX5 and have been a member of the MX5 members club, which sends us regular magazines, and the membership also gives us discounts on servicing at a Mazda dealer.
#
# Is there a similar owner's club in the UK for NEW Fiat 500 owners?
#
# I notice this website:
#
# http://www.fiat500club.org.uk/
#
# ...but it appears to be for the older models, or maybe it's just not kept up to date?
#
# This is the kinda thing I'm looking for, but for the new Fiat 500:
#
# http://www.mx5oc.co.uk/
# Processing post URL: https://www.fiatforum.com/threads/is-this-head-salvageable.508961/post-4753987
# Post page response status code: 200
# Title: Technical Is this head salvageable?
# Content: Hi!
# I bought a 650cc engine with some bits missing on the cheap in order to convert it to a semi-hot 695cc. Basically I only wanted to use the crank case, crankshaft and cylinder head as the rest of it is getting replaced anyway.
#
# When I took of the head I was greeted with this (see attached photo)... Well, I now know why the engine had bits missing!
#
#
# I have a couple of questions:
#
# WTH happened here? I've seen faulty head gaskets before, but never this kind of carnage... And I suspect that not all damage (of any!) is caused by a leaking head gasket, there is evidence of mechanical damage too, almost as someone was trying to grind away material with an angle grinder. But why?
# Is this head salvageable, or would I be better off getting a new head? The plan was to skim the head, get bigger valves and smooth out the ports so extensive work is going to be done on the head anyway, no matter if I buy a "new" one or not. But I am curious as to what you think: is this damage repairable?
# Processing post URL: https://www.fiatforum.com/threads/new-member-from-the-netherlands.506128/
# Post page response status code: 200
# Title: 500 New member from The Netherlands
# Content: Hi there. I´m new on this forum. Investigating how its working.
# We do have 3 fiat 500 in our family. My wife, doughter and our doughter in law.
# As I can´t find any good forum in the Netherlands, Im loking now over the borders and found this in th UK.
# hope I can find here usefull information.
#
# best regards,
# Al.
# Processing post URL: https://www.fiatforum.com/threads/fiat-500-most-likely-car-to-be-vandalised-in-uk.298326/
# Post page response status code: 200
# Title: Fiat 500. Most likely car to be vandalised in UK.
# Content: Found this. Not good news.
# http://uk.cars.yahoo.com/news/-fiat-500-named-the-most-vandalised-car-on-uk-roads.html
# Processing post URL: https://www.fiatforum.com/threads/importing-an-eu-spec-fiat-500-into-the-uk.455926/
# Post page response status code: 200
# Title: Technical Importing an EU spec Fiat 500 into the UK
# Content: Hi Guys,
#
#
# Chances are I am moving to the UK from GR and I want to bring my Fiat 500 with me, so that means import it and make it UK plates!
#
# From what I see, I need to do a few things, which include
#
# 1. Getting a Certificate of Conformity from Fiat
# 2. Changing the Speedo to show MPH
# 3. Changing the headlights directions
# 4. Changing the rear foglight.
#
# Does anyone have experience in dealing with this? Thanks, much appreciated!
# Processing post URL: https://www.fiatforum.com/threads/prices-for-uk-500-announced.123001/
# Post page response status code: 200
# Title: General Prices for UK 500 Announced!
# Content: Prices have FINALLY been announced for the 500 in the UK!
#
# 1.2 Pop £7,900
# 1.4 Pop £9300
# 1.3 MultiJet Pop £9300
#
# 1.2 Lounge £9,300
# 1.4 Lounge £10,700
# 1.3 MultiJet Lounge £10,700
#
# 1.2 Sport £9,300
# 1.4 Sport £10,700
# 1.3 MultiJet Sport £10,700
#
# So basically you add £1400 for a larger engine and/or another £1400 for the next trim level. Here's the full press releases...
#
# THE NEW FIAT 500 – YOURS FOR UNDER £8,000!
#
# Fiat Group Automobiles UK Ltd has just announced prices of the eagerly-awaited new Fiat 500, which goes on sale here in January.
#
# With a starting price of just £7,900 OTR, the new Fiat 500 represents outstanding value for money and positions the car well below its benchmark rivals. At the top end of the range, a highly specified version with a larger engine costs only £10,700 – an OTR price that includes air conditioning and alloy wheels as standard.
#
# Available with a choice of three frugal, ultra-low emissions, Euro 5-ready engines: 69 bhp 1.2-litre and 100 bhp 1.4-litre petrol, or 75 bhp 1.3-litre MultiJet turbodiesel, the new Fiat 500 can be ordered in three different trim levels – Pop, Sport and Lounge.
#
# Standard equipment in the entry-level Pop includes ABS anti-lock brakes with EBD, driver, passenger, side and driver’s knee airbags, radio/CD/MP3 player, power steering, electric mirrors, colour coded bumpers and chrome-plated door handles. The extensive options list includes ESP, glass sunroof, metallic paint and parking sensors.
#
# Sport and Lounge versions start at £9,300, while specifying a larger engine in any trim level adds £1,400. Standard equipment on both Sport and Lounge versions includes the Blue & MeTM hands-free media system, air conditioning and 15” alloy wheels. Sport specification includes a rear roof spoiler, fog lights, sports interior and dark tinted rear windows, while Lounge trim includes a split, folding rear seat and fixed glass roof.
#
# The simple pricing structure means that any combination of car is possible – customers simply start with a 1.2 Pop and add £1,400 for a more powerful engine, £1,400 for a higher trim level, or £2,800 for any combination of both. A huge list of style options – created specifically to offer customers wide-ranging opportunities for personalising the interior and exterior of their vehicles – is also available.
#
# “There has been widespread speculation about Fiat 500 prices this year and we’re delighted now to be able to reveal them,” says Elena Bernardelli, marketing director, Fiat Group Automobiles UK.
#
# “We wanted to create a classless car for everyone, that was not just about being a well-known badge, and with this pricing structure I believe we have introduced a model to the UK that will be within the reach of a wide range of customers.”
#
# The Fiat 500 goes on sale through Fiat’s 162-strong UK dealer network in January 2008.
# Processing page URL: https://www.fiatforum.com/search/887488/?page=3&q=fiat+500+uk&o=relevance
# Page response status code: 200
# Found post links:
# Processing post URL: https://www.fiatforum.com/threads/a-kind-of-new-jeep-based-on-an-fca-platform.505482/
# Post page response status code: 200
# Title: A (kind of) new Jeep? (Based on an FCA platform)
# Content: I’ve just seen an ad for the ‘Jeep Avenger’. Available in the UK since last June. What caught my eye was actually the interior which looks quite identical to the current new Electric 500. Identical drive mod buttons and touch screen…
#
# Given the timelines this must have been drawn up and put out to market well into the Stellantis merge.
#
# Could there be more modern Fiats yet to come using Fiat (FCA Fiat) era / designed platform / tech?
# Processing post URL: https://www.fiatforum.com/threads/help-fuel-cut-off.505490/
# Post page response status code: 200
# Title: Technical Help Fuel Cut Off
# Content: Hello All,
#
# I have a fault of the dash as Fuel Cut Off unavailable, Airbag light & flashing mileage. I have had a computer on the error came back as a electrical fault, I have tried a new battery, and the garage tried to delete the errors. Can anyone advise, the car is a Fiat 500 Lounge, year 2014 UK model.
#
#
# Thank you
# B
# Processing post URL: https://www.fiatforum.com/threads/convertible-2015.503575/
# Post page response status code: 200
# Title: 500 Convertible 2015
# Content: Coral Fiat 500 convertible 2015 (65 reg) UK
# Processing post URL: https://www.fiatforum.com/threads/uk-registered-abarth-500.175683/
# Post page response status code: 200
# Title: General UK Registered Abarth 500
# Content: Look what's sitting in the carpark at Fiat HQ......
# Processing post URL: https://www.fiatforum.com/threads/travelling-long-distance-with-a-35-000-miles-fiat-500-l.498476/
# Post page response status code: 200
# Title: General Travelling long distance with a 35,000 miles Fiat 500 L
# Content: Hi all,
#
# Just a few questions as I haven't driven on a motorway before, let alone my Fiat 500 for over an hour in a single journey.
#
# Firstly, my Fiat 500 L has done just under 35,000 miles and I use it daily to travel to work. A trip each way can put 26 miles onto the clock. This makes me concerned about wear and tear on the engine whenever I do a long journey.
#
# In April I will be travelling from Westfield, a village near Hastings in the UK, to Quedgley near Gloucester. This will take me about three hours and thirty mins, then we will be off to the Teddy Rocks Festival in Dorest in which we will be taking my friends car. Then after the festival three days later, I will be doing the journey from Quedgley to Westfield. A total of seven hours worth of driving on the car.
#
# I will then in August be doing the same trip, going to Quedgley from Westfield, then taking the train to Devon for the Gone Wild Festival, then taking the train back up to Gloucester. After that I will then be driving to Cheshire for an hour and a half going to a festival there and then back the sams night being two hours and 20 mins more in total across the two trips, then from Gloucester to Quedgley the next day for another three hours and 30 mins trip.
#
# With all this said, will my car by any chance withstand all this?. A Fiat 500 L only has a small engine on it, not a massive tank-like thing, so is the car durable for all this in the timeframes mentioned?. Has anyone on these foruks used their Fiat 500 L on such long trips regularly?.
#
# I appreciate I need good oil levels, tire pressures to the required level, radiator antifreeze topped up and know the petrol stations on my route.
#
# Many apologies for the long post and seemingly stupid questions, but this is a new thing I would really like to do and cannot trust the trains anymore.
#
# Many thanks in advance and I look forward to engaging on the forums and asking any questions you may have.
# Processing post URL: https://www.fiatforum.com/threads/fiat-500d-1964-history-paperwork-stockist-how-to-find-history-information-images.502909/post-4702831
# Post page response status code: 200
# Title: General Fiat 500D 1964 - History - Paperwork - Stockist - How to find history information images?
# Content: Hi All
#
# Im looking for clues or if anyone has information about a fiat 500D 1964D light blue RHD or how to go about obtaining history etc. Ive filled out a v888 document has anyone had any luck with this? The only indication i have is that the car came from Taylor & Hales (woodgate) in farnham common. The car is a UK RHD
#
# Any ideas would be appreciated as to how others have been successful in obtaining information?
# Processing post URL: https://www.fiatforum.com/threads/here-it-is-officially-the-new-panda.506691/post-4731839
# Post page response status code: 200
# Title: Here it is, officially the new Panda
# Content: A video dropped today officially announcing the new Panda,
#
# Here are a couple of screen grabs from that video
#
# The video is available to see on the Fiat YouTube page
#
# I would expect this is still a concept to some degree and will change a bit by the times it is launched but this is what the CEO is saying the new panda will be
#
# There is also talk of there being a panda XL a new larger SUV and a Panda XXL which could be positioned as a camper or large family people carrier/van
#
# Looks like “Panda” is soon to become a brand of its own
#
#
#
#
#
#
# I should also add that the official launch date of the next Fiat car which will undoubtedly be the panda is the 11th of July 2024 with new cars to follow every year for the next 4 years meaning a new car in 202, 25, 26 and 27
# Processing post URL: https://www.fiatforum.com/threads/radios-stations-unavailable-for-a-few-seconds-then-unavailable-then-back.505295/
# Post page response status code: 200
# Title: Technical Radios stations unavailable for a few seconds then unavailable then back
# Content: I noticed from few weeks that my radio at start plays a radio station for few seconds then no more stations are unavailable for a while...then the radio station plays again as normal after a few miles.
# What could be the reason??? Could it be a wiring fault? I tried to clean my antenna but no joy... My car is a Fiat 500 2019 and in UK.
# Tyia!!!
# Processing post URL: https://www.fiatforum.com/threads/most-expensive-500-in-the-uk.134745/
# Post page response status code: 200
# Title: General Most Expensive 500 In The Uk !!
# Content: Hello there fellow FIVE HUNDREDIANS,
#
# I have decided to move on from a 56 plate Grande Punto M-Jet Sporting to an even cooler motor vehicle...
#
# It would seem that my 500 shall be the most kitted out 500 possible in the UK market..
#
# I have today bought a Fiat 500 1.3 Multijet Sport with the following options :
#
#
# Pasadoble Red
# Red Leather and Black Ambience
# 15" 2 tone Sports Alloys
# Side Mouldings inc space for Italian 500 badge
# Chrome Wing Mirrors
# White Side Stripe
# Climate Control
# Auto dipping Rearview Mirror
# Sky Window
# Parking Sensors
# ESP
# Side Skirts
# Front Spoiler
# Rear Dam Valance
# Chrome Bonnet Strip
# Black Clothes Hangar
# Italy badge on Wing
# Italia Key Covers
# Carpets
#
#
# Total £14,124
#
# Was given £8000 part exchange for my 56 Plate 25k Mileage Grande Sporting which I'd say is awesome for a car that isn't in the best condition and should really at most be worth £7k
#
# What do you think?? Have I had a good deal?
#
# I'm guessing and hoping that everyone else has paid RRP for their 500 cos of Fiat wanting to ensure the resale value is good... (I was told if Fiat catch a dealership discounting a 500 they'll be terminated)
#
# The estimated delivery is End of April/May
# Processing post URL: https://www.fiatforum.com/threads/nuova-500-newbie-uk.296361/
# Post page response status code: 200
# Title: Nuova 500 Newbie - UK
# Content: Hello everyone and nice to see a lively forum for Fiat owners!
#
#
#
#
#
#
# My name is Richie, I live on the Wirral in the UK, just a few miles across the Mersey River from Liverpool.
#
# I am the very proud owner of a 2008 registered, 500 Sport in Crossover Black metallic which I collected on Monday. It's got the 1.3 Multijet turbodiesel and half leather black interior. I traded my 2004 Focus ST170 in for the Fiat, main reasons being the need for much better fuel economy and cheap tax (sad sign of the times) but also the need for something with character!
#
# I've owned a lot of sporty cars over the years - Ford Puma 1.7, Focus ST, Focus Zetec, Pug 206GTi, sporty Clios, etc. I am a petrolhead through and through and cars are a huge part of my life.
#
# I know I've only had it a few days but so far the Fiat is exceeding all expectations and proves that motoring on a budget is not miserable at all! Far from feeling downsized and shortchanged after the fairly luxurious ST, the 500 feels more upmarket and homely. I've had my fun with speed, now it my time to chill and enjoy the view...
#
# Anyway, some pics to share
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 'He's' been christened Gino, and my neighbour Alison who has a 2010 500C Lounge 1.2. We call them 'Ying and Yang' when parked outside
#
#
#
#
#
#
#
# Look forward to getting to know the forum and enjoy the cheerful fun of the 500!
#
# Cheers!
#
# Richie
# Processing post URL: https://www.fiatforum.com/threads/whimsical-fiat-500-cushion.456699/
# Post page response status code: 200
# Title: General Whimsical Fiat 500 Cushion
# Content: Maybe a bit naff?
#
# http://www.ebay.co.uk/itm/DACHSHUND...350667?hash=item4415abb50b:g:VoIAAOSwBt5ZD8z0
# Processing post URL: https://www.fiatforum.com/threads/any-fiat-500s-in-oxford-uk.157852/
# Post page response status code: 200
# Title: General Any Fiat 500s in Oxford UK
# Content: Hi there 500 lovers,
#
# I have recently ordered one of these beauties in red sports here in India, but will be getting it only by End of Nov. Or early Dec. During that time I will be in Oxford Uk for my university, so I was wondering if anybody from Oxford or nearby could show me there 500 and take me for a little ride around the town  (I'll pay for the fuel).
#
# Cheers
#
# Omar
# Processing post URL: https://www.fiatforum.com/threads/current-fiat-uk-website.322172/
# Post page response status code: 200
# Title: Current FIAT UK Website
# Content: Oh what have they done!!!!! ?????
#
# The current Fiat UK Website is the worst they have ever produced.
#
# Home page is a clunky "appeal to the brain dead" fashion followers and lacks links to many models such a the Bravo etc. etc. If you want a 500, 500L, Panda or possibly a Punto then the home page will possibly help you. All other models a buried very deep within the website.
#
# I couldn't but help think the home page design and style was more akin to a condom website. Seriously a total xxx yyy zzz IMHO. Maybe it is my age, maturity, intelligence and general sensibility that is depriving me of the stunning joys and appeal of the website design? As for the missing models .........
#
# Shame on you Fiat UK!!!!!!
#
# I also took the time to complete their survey giving them 1 out of 100.....not that anybody will ever take any notice of a loyal Fiat car purchaser/owner since 1974 .........
# Processing post URL: https://www.fiatforum.com/threads/my-past-four-uk-fiats.236384/
# Post page response status code: 200
# Title: Stilo My past four UK Fiats
# Content: Just for completeness, here is my past four UK Fiats I've owned all from new.
#
# Fiat Cinquecento SX ('96)
#
# Sadly I don't have a picture on the computer of this one, but this is what it did look like. Sorry if this is your pic, I'll remove it if it is.
#
#
#
# Fiat Bravo 1.3 SX ('98)
#
# Sorry for the poor picture quality, but digital cameras where not so good back then!
#
#
#
# Fiat Bravo 1.6 100 16v HLX ('01)
#
#
#
# Fiat Stilo 1.6 16v Dynamic ('02)
# Processing post URL: https://www.fiatforum.com/threads/agreed-value-insurance-uk.424690/
# Post page response status code: 200
# Title: General Agreed Value Insurance UK
# Content: Does anyone in the UK have agreed value insurance on their 500. I am insured with Peter James but you need a reputable Classic Fiat 500 specialist to value it.
#
# It used to be the Fiat 500 club UK who offered this service but since the unfortunate early death of their chairman, they are unable to offer valuations.
#
# They have suggested Middle Barton or Proietti may be able to? Anyone have any other leads?
#
# I am not sure what the classic car insurers value a 500 at but I would imagine it is well below their true value.
#
# Tony
# Processing post URL: https://www.fiatforum.com/threads/another-dealer-quits.502459/post-4702826
# Post page response status code: 200
# Title: Another Dealer Quits
# Content: Fiat and NSU, Steyr Puch, Nasr, Turkey Poland, South America, South Africa and some built in Oz I believe to name a few…the first Harrods delivery vans were fiats…how the mighty have fallen
# Processing post URL: https://www.fiatforum.com/threads/how-do-you-modify-lhd-fiat-500-headlights-for-rhd-use-in-uk.329452/
# Post page response status code: 200
# Title: General How do you modify LHD Fiat 500 headlights for RHD use in UK?
# Content: I am currently importing a LHD Fiat 500 from Italy, and I understand that the headlights need modding or replacing for use here in the UK.
# What have other people done to conquer this problem?
# And also is that all that needs changing for our UK mot?
# Thanks,
# Adam.
# Processing post URL: https://www.fiatforum.com/threads/heater-problem.493467/
# Post page response status code: 200
# Title: Technical Heater problem
# Content: Hi guys,
# Just got 500 for my wife...
# I have the famous "heater works only on 4".
# I have replaced the heat resistor but there is no change.
# The plug looks alright, fuses are fine as well.
# Could you guide me what could be...
# The car is 500 POP 2009
#
# A bit details:
# I've located the heat resistor plug next to the clutch on UK variant. There wasn't any screws holding the plug ,was basically hanging from above. I guess the previous owner tried to fix but no luck.
#
# Is it worth taking off all the central console ( heat box) and try to measure some voltages around.
# Ps.sorry for my English...hope u understand my concerns
# Thanks for your time in advance
# Processing page URL: https://www.fiatforum.com/search/887488/?page=4&q=fiat+500+uk&o=relevance
# Page response status code: 200
# Found post links:
# Processing post URL: https://www.fiatforum.com/threads/2009-fiat-500-1-2l-exhaust.242927/
# Post page response status code: 200
# Title: General 2009 Fiat 500 1.2l Exhaust
# Content: Where is the best place to get an after market sports exhaust for my 2009 fiat 500 in the uk?
# Processing post URL: https://www.fiatforum.com/threads/what-fiat-uk-say-about-the-5yr-warranty.134941/
# Post page response status code: 200
# Title: General What Fiat UK say about the 5yr warranty
# Content: "In the UK no press release mentioned the 5 Years Warranty, this is something that has been communicated in other markets.
# We planned to communicate the 5 Years Warranty when it was ready in the UK. Since people have heard about it from other markets we will also give all customers who bought the car since the launch with the relevant finance package (50 to 500 and 500p per day) the opportunity to purchase this warranty when it will be launched here in the UK.
# This is a special gesture by Fiat UK to demonstrate our confidence in the product and to satisfy those keen customers who have followed the birth of the new Fiat 500 since its launch in Italy." from the Fiat UK forum
#
# Does anyone want to sign up the 50:50 deal without the warranty price?
# Processing post URL: https://www.fiatforum.com/threads/automatic-fiat-500.324482/
# Post page response status code: 200
# Title: General Automatic Fiat 500
# Content: Hi
# Wonder if anyone can help me I live in Cheltenham Gloucestershire UK I have been looking for a Fiat 500 automatic for sale second hand. I've been having no luck all the one's i've found have been miles away. If anyone could give me any advice that would be great.
# Processing post URL: https://www.fiatforum.com/threads/fiat-500-drl-wiring-colours.481987/
# Post page response status code: 200
# Title: Technical Fiat 500 drl wiring colours.
# Content: Hi, sorry if this is the wrong area to post as I've just joined.
#
# I want to replace the bulb holder for the fiat 500 nearside drl. The wiring colours are black, orange and white/grey. Can someone please tell me what fiat has coded these wires as? I can't find a reliable diagram for my 2012 model. I'm also in UK if that helps.
#
# See picture attached of my drl connector.
# Processing post URL: https://www.fiatforum.com/threads/a-crack-in-the-dashboard.358328/post-4694138
# Post page response status code: 200
# Title: General A crack in the dashboard
# Content: My Fiat500 Lounge was bought in 2014. Its 4 Years and few months old. It developed a crack about 2 months ago. Fiat is only covering for 30% of parts and I have quoted overall $3000 by the dealership for 70% of parts and Labour... its shocking !!
# Processing post URL: https://www.fiatforum.com/threads/at-a-glance-fiat-clubs-in-the-uk.548/
# Post page response status code: 200
# Title: At a glance: Fiat clubs in the UK
# Content: EASTCOAST-FIAT-CLUB
#
# Clubcento: www.clubcento.co.uk
# THE owners club for Cinquecento and Seicento
#
# Fiat Coupe Club UK: www.fccuk.org
# Owners club for Fiat Coupe. 100 members in 6 different countries so far.
#
# Bravo Register: www.bravo-guide.co.uk
# Not a club so much as a register for Bravos / Bravas. Run by AlfaNige as part of the Fiat Bravo Guide.
#
# Fiat Motor Club GB: www.fiatmotorclubgb.com
# Caters for all Fiats from 1899 to the current Stilo thingy.
#
# Punto Sports: www.puntoabarth.co.uk
#
# Fiat 500 Club: www.fiat500club.org.uk
# The owners club for the best small Fiat - the 500.
#
# If you have quick links to Fiat clubs in the UK post in this one, so it appears all the time. There will be another one for non-UK clubs shortly.
#
# regards,
# Paul
#
# www.fiatbravo.org.uk - [email protected]
# Current Fiat fleet:
# '98 Seicento Sporting - '02 Punto Sporting - '94 Tipo 1.4 ie S
# Processing post URL: https://www.fiatforum.com/threads/fiat-500-ron-arad.357085/
# Post page response status code: 200
# Title: General Fiat 500 Ron Arad
# Content: http://www.fiat.co.uk/uk/500/500-Ron-Arad
#
# Err, did anyone else notice this?!
# Processing post URL: https://www.fiatforum.com/threads/advice-fiat-500-classic-parts-source-in-italy.476367/
# Post page response status code: 200
# Title: Advice: Fiat 500 Classic parts source in Italy
# Content: Hi
#
# Looking to buy some 500 Giardiniera parts (soft top frame + accessories + trim).
#
# Could anyone recommend a reputable, classic Fiat 500 spare parts company in Italy that ships to the UK?
#
# Many thanks
# Processing post URL: https://www.fiatforum.com/threads/new-fiat-500-awarded-best-urban-electric-car-at-the-2022-drivingelectric-awards.491337/
# Post page response status code: 200
# Title: 500 (Electric) New Fiat 500 awarded Best Urban Electric Car at the 2022 DrivingElectric Awards
# Content: New Fiat 500 named the first winner of Best Urban Electric Car at the 2022 DrivingElectric Awards
# Praised for its agility, driving style and range
# In 2021, New 500 has already scooped a portfolio of awards including Best Small Electric Car for the City by WhatCar? and Auto Express’ City Car of the Year
# New Fiat 500 has picked up further recognition as the go to electric car, having most recently been announced as Best Urban Electric Car at DrivingElectric’s 2022 Awards.
#
# For the fourth ever DrivingElectric Awards, and the first year to feature the ‘Best Urban Electric Car’ category, the New Fiat 500 has continued to build on its success in previous years.
#
# Judges praised the New 500 for setting itself apart from its competition thanks to its impressive fun driving style, nippy agility and range.
#
# Richard Ingram, Editor, DrivingElectric, said: “Last year’s DrivingElectric Car of the Year, the Fiat 500 is still the best in its segment. Reinvented for the electric era, this retro take on the evergreen small car is nippy, agile and fun to drive – with a range that will satisfy urban drivers twice over.”
#
# New Fiat 500 is the first fully-electric Fiat designed from the ground up. The car provides a raft of best-in-class features such as Level 2 Autonomous Driving technologies, a variety of battery options and a substantial driving range of up to 199 miles (WLTP) – the longest range of any electric city car on the market today. The New 500 is also the only 4-seater convertible in its segment.
#
# The sustainable philosophy of the New 500 is reflected not only in the electric powertrain but also within the interior. The seats are partly made with Seaqual® yarn, the weaving of which produces a material derived from recycled plastic, 10 per cent of which originates from the sea and 90 per cent from land.
#
# Greg Taylor, Fiat UK Country Manager, said: "With this award, we continue to mark the arrival of New 500 and celebrate its success within the UK and globally. It marks a pivotal moment in making sustainable, connected, and autonomous mobility accessible to UK motorists.
#
# “With a host of features such as an all-new infotainment system, plus a convertible option and Level 2 Autonomous Driving – which are both exclusive to New 500 within its segment – as well as four trim levels, there is a New 500 for everyone.”
# Processing post URL: https://www.fiatforum.com/threads/seatbelt-fiat-500.436443/
# Post page response status code: 200
# Title: seatbelt FIAT 500
# ...
#
#
# Have to say based on that I wouldn't want to instruct in a 500.....
# Processing post URL: https://www.fiatforum.com/threads/whats-not-covered-in-the-3rd-year-warranty.240166/post-2524510
# Post page response status code: 200
# Title: General What's NOT covered in the 3rd Year Warranty?
# Content: I've just been to Stoneacre fiat in Peterborough who tell me it needs 4x new glow plugs (£19.95) and a new control unit (£79.99) plus labour. They are waiting to see if Fiat will cover it as part of the third year dealer warranty as it's just over two years old. I must say I am surprised that all 4 glow plugs need replacing and it needs a new control unit. It only has 20k on the clock and I am always careful not to turn the engine till the glow plug sign goes out. I hope Fiat will cover this or else I will be very disappointed and out of pocket. Will let you know whether this is covered or not.
# Processing post URL: https://www.fiatforum.com/threads/a-little-bit-of-buying-advice.150212/post-1584795
# Post page response status code: 200
# Title: General A little bit of buying advice?
# Content: Hi Guys!
#
# Was just dropping in from the panda section to ask a quick fav
#
# I'm going to go look at this tomorrow
#
#
#
#
#
#
# http://belfast.gumtree.com/belfast/29/24666529.html
#
# What it dosent say is that it's got 96,000 miles on it and there's very little history....
#
# Thoughts?
#
# Jim
# Processing post URL: https://www.fiatforum.com/threads/knackered-suspension.274976/post-2805966
# Post page response status code: 200
# Title: General Knackered suspension
# Content: jrkitching said:
#
#
#
# My old Renault 5 did 217k with only the bottom balljoints needing replacement at 140k; the rest of the suspension & steering lasted the life of the car. My Ford Ka managed 101k with just one front wishbone; my Suzuki Van @ 117k needed nothing at all. Notice the pattern here?
#
# Click to expand...
#
#
# Those manufacturers don't get their suspension components from the Leerdammer factory?
#
# A couple of links for those who want decent suspension bits for Panda's......
#
# Top mounts.....
# http://seekpart24.com/fiat/panda-169-03/1-2-2/suspension-strut-bearing-100371
# Wishbones
# http://seekpart24.com/fiat/panda-16...ks-wishbone-trailing-link-diagonal-arm-100571
# Rack ends and tie rod ends
# http://seekpart24.com/fiat/panda-169-03/1-2-2/steering-joints-100198
# Dampers
# http://seekpart24.com/fiat/panda-169-03/1-2-2/shock-absorber-100121
# Droplinks
# http://seekpart24.com/fiat/panda-169-03/1-2-2/self-aligning-support-100590
#
# All cheaper and far better quality than the tat you'll get from a stealer.
# Processing post URL: https://www.fiatforum.com/threads/driving-my-new-500-back-from-italy.441482/
# Post page response status code: 200
# Title: General Driving my new 500 back from Italy
# Content: So, I am visiting my dad in Italy and whilst here I thought it might be a great idea for me to buy an old Fiat 500 and drive it back via the south of France to the UK. 900 plus miles at 45mph...gulp!
#
# Meet Sofia. Named after the seller's daughter. Richard (a mate) has a 500 and knows them well. He told me a few things to look out for. Mainly don't be blinded by a shiny one and absolutely avoid one that looks like it was crashed.
#
# Sofia looks pretty shiny and I think there's some evidence of a crash repair up front on the panel behind the battery. So it's good job I spoke to an expert before I bought the car. Also it's Ivory, so basically beige. But to me it looks good. So I keep telling myself. It's been repainted in the orginal dcolour at some point and the job looks reasonable if not perfect. Can't find much evidence of filler so that is reassuring.
#
#
# The gearbox is a bit rough, worse than the others I tried. Double declutch with a blip of throttle is the only way to stop crunching into second and third and even then it still clunks quite unhappily. Good project for my mate Richard when I get back.
#
# More info will of course follow in due course. Couple of pics for now attached.
#
#
# Any advice on pre journey checks would be appreciated. I have some basic tools here and have bought spare points and plugs. Also want to do an oil change which im sure will be easy (simple car and I've done lots on other cars) but is there anyhting online that shows the procedure? are there tricks to be aware of? or just warm it up, pull sump plug and then refill? Is the oil level checked warm or cold? I looked at the guides available here but could find nothing on an actual engine oil change...
# Processing post URL: https://www.fiatforum.com/threads/hello-from-america.278859/post-2835225
# Post page response status code: 200
# Title: Hello from America!
# Content: My name is Brandon and I've placed the order for a new 500 sport. I walked in the door of a dealership in Texas and left with every intention of buying one. all that said im a bit of a purest when it comes to proper imports (any thing from Europe) I love the car but im not a big fan of everything US spec about it. The first thing I want to change is the wheels, I have chosen the 16" Multispoke alloys that came on the UK spec lounge. But i have no idea how I would "import" a set of wheels. I'm wandering if any one out there would have any thoughts on that?
#
# Thanks!
# Brandon
# Processing post URL: https://www.fiatforum.com/threads/fiat-500bygucci-cabriolet-to-be-released.281443/
# Post page response status code: 200
# Title: 500 FIAT 500byGucci Cabriolet to be released
# Content: As a result of the interest attracted by Fiat’s 500byGucci model – 3000 pre-orders logged on the www.500bygucci.com website and requests from all over the world – Fiat and Gucci are now introducing a cabriolet version – the Fiat 500CbyGucci.
#
# Customised by Gucci Creative Director Frida Giannini in collaboration with Centro Stile Fiat, the car will be distributed worldwide, and from this month will be available to order both online at fiat.co.uk and in selected Fiat UK dealers. Prices start at £17,800 OTR.
#
# All the exclusivity of the Fiat 500byGucci is enhanced by the innovative electrically operated full length soft top in this new version. It will be available in two sophisticated body colours: white with glitter and brushed chrome-plated elements, and black with glitter and shiny chrome-plated accents. For both, the soft top is black with the characteristic green-red-green Gucci web pattern printed lengthwise.
#
# The exterior of the Fiat 500CbyGucci is embellished by 16” alloy wheels characterised by the unmistakable retro design of the spokes. The hub caps have a double G logo in matching body colour, and Gucci signatures in italics are displayed on the tailgate and door pillars.
#
# The passenger compartment of the Fiat 500CbyGucci also brims with eye-catching features: stylish stitching, exclusive materials, satin and polished chrome-plated elements, a velvet-effect finish on the radio panel, and two-tone Frau leather seats with Guccissima print. The Gucci web theme also appears on the seats, gearbox, key cover, mats, and, with an innovative finish, on the seat belts.
#
# Fiat 500CbyGucci will of course come complete with comprehensive standard equipment: automatic climate control system, seven airbags (front, side, window and knee), Blue&Me system integrated with rear parking sensors, car radio with CD-MP3 player and leather steering wheel with radio controls.
#
# The selected Fiat dealerships that will be displaying the Fiat 500byGucci range will receive copies of an exclusive lifestyle brochure created as a fashion catalogue and designed to bring out the unique, one-of-a-kind nature of this extraordinary interpretation of the glamorous world of the Fiat 500.
#
#
# ​
# Processing post URL: https://www.fiatforum.com/threads/port-68r-adapter-for-smartphone.348127/post-3459786
# Post page response status code: 200
# Title: Technical Port 68R adapter for Smartphone
# Content: First of all I wanted to say hi as I'm a new on the forums.
#
# I just bought a fiat 500 for my girlfriend.
#
#
# The car is 2010 and is equipped with the 68R Port option and a Blue&Me Map satnav device (using TomTom maps). Unfortunately both the device, and the maps (dated 2009) are terrible so to speak.
#
#
# As everyone now has a smartphone and in my opinion a standalone satnav device is a thing of the past I started to look for a smartphone cradle / adapter for the 68R port.
#
#
# I was quite surprised that I could not find anything in google or on ebay.
#
#
# Hence my question, has anyone seen a port 68R smartphone holder or a 68R / USB adapter?
#
#
# I know that I can off course use a standard one with a USB cigarette charger however having already the nice port I wanted to avoid additional cabling and a dedicated smartphone adapter seems like a perfect solution.
# Processing post URL: https://www.fiatforum.com/threads/first-experience-of-a-fiat-dealer.131935/
# Post page response status code: 200
# Title: General First experience of a Fiat dealer........
# Content: ..... and what can I say, it's been rubbish!
#
# I'd heard that Fiat/Alfa dealer network were a little wanting in their customer focus, but from my first experience it's already not looking good.
#
# My girlfriend has decided that she wants a 500, we saw them in Italy in September and have been eagerly awaiting for the UK launch. Been online chosen the spec etc, now for visit to the dealer.
#
# Sunday morning, the salesman was nice enough, but knew nothing about the car! Took our details, gave us a trade in price, let us loose for a test drive. Everything's going great, promised to get back to us on Monday with a finance quote.......
#
# We haven't heard anything from them, so my girlfriend called today. They had no record of our visit, couldn't identify which salesman it was even though there were only two of them working! So took our details again, offered us less as a trade in price, questioned why my girlfriend wanted to trade her car in against a new 500 as her cars got a better spec and more 'toys'!
#
# They've quoted a July deliver date because of the spec we'd chosen. 1.2 Lounge, red, red and ivory leather and the italian strip over the top.
#
# We'll be going to a different dealer, fingers crossed they're better!
#
# Rant over. It's my first post too.
# Processing post URL: https://www.fiatforum.com/threads/definitive-service-costs.260830/post-3330841
# Post page response status code: 200
# Title: General Definitive service costs
# Content: chas379 said:
#
#
#
# Tony, never gave it a thought and it wasn't mentioned. Mind you I am fragrant enough so don't suppose it matters re the filter.:devil:
#
# Click to expand...
#
#
# For some completely inexplicable reason not having your pollen filter changed can invalidate the warranty - this has been discussed at great length on the Abarth Forum. Apart from anything else it will reduce the risk of Legionella.
# Processing post URL: https://www.fiatforum.com/threads/fiat-500-values.352762/post-3510406
# Post page response status code: 200
# Title: General Fiat 500 values
# Content: Whats happening to the world of 500 classics?
# Is there a limit people are willing to pay?
#
# This poor old 500L is about the same condition as mine was.
# I paid £1300 for mine.
# this is already at £1719
# http://www.ebay.co.uk/itm/FIAT-500L-BLACK-/191237147597?pt=Automobiles_UK&hash=item2c869f4bcd
#
# and this one is now £870
# http://www.ebay.co.uk/itm/FIAT-500L...1027279?pt=Automobiles_UK&hash=item3a9365d3cf
# This appears to be beyond salvageable.
#
# Prices seem to be rising for a complete junker and yet an on the road ready to drive model can be had for as little as £2500 with an MOT. Okay it may still need a renovation.
#
#
# is this the dearest 500F model at £28995?
# http://www.autotrader.co.uk/classif...an_1l/maximum-age/over_10_years_old?logcode=p
#
# and maybe the dearest 500 at £38995? apart from the Jollies
# http://www.autotrader.co.uk/classif...ld/advert-type/standard-listing?logcode=ucnnp
#
# Is the world going 500 mad or is it just a good investment?https://cdn-i.fiatforum.com/images/smilies/confused.gif
# Processing post URL: https://www.fiatforum.com/threads/hello-joined-cos-im-interested-in-the-new-fiat500.104435/post-1121069
# Post page response status code: 200
# Title: Hello...joined cos I'm interested in the new fiat500
# Content: Hello
# My name is Kevin B.
#
# I am an property developer from the East Midlands (based in Lincoln) with a liking for little cars....especially little Fords and little Fiats.
#
# I have a Ford Ka at the moment, but it looks like the new Fiat500 will be an absolute stunner with a quality far beyond anything Ford are offering, so I have joined this forum to try and keep up to date with what's happening regarding Fiat 500s launch.
#
# I suspect Fiat have probably already sneaked a LHD version of the 500 into the UK already for their senior staff and dealers to look at......if anyone knows where I can see one in the UK, let me know
#
# :worship: (Do we have any Fiat dealer staff on the forum I wonder?):worship:
#
# Thanks
#
# Kevin B
# Processing post URL: https://www.fiatforum.com/threads/blue-me-sat-nav-blue-me-map-updates.214826/post-2312488
# Post page response status code: 200
# Title: Blue & Me Sat Nav - Blue&Me Map - updates .?
# Content: Hi
#
# Yesterday I picked up my 500 MultiJet Lounge - so I am posting 2 or 3 threads with some newbie questions about various aspects :
#
# I have the Blue&Me Map - Sat Nav
#
# I bought this because I like the dashboard-mount - no wires.
# Also I like the proper integration to the Blue&Me - so it dips the radio/audio to read the navigation commends 'turn right' etc.
#
# I've not had Sat Nav before - my phone has a cut-down Google Maps/GPS/Directions thing - but not true SatNav.
#
# *** 2 main questions :
# o I drove on a (relatively) new peice of by-pass yesteray - but the B&M Map didn't know about it so I was effectively driving in fields on the screen - it got quite confused - I assume somewhere I download and update the maps .? How can I tell the version/age of the maps I have .? The Help/About tells me about the speed camera database... Any help there please.
# o I dont seem to be able to do a full postcode search - I input the first 1/2 of the postcode - it then offers me the next set of numbers - then wants street names - I live deep in rural Cornwall. Most roads dont have a name and most houses dont have a number - so as an example I wouldn't be able to find my own house even if I knew the full postal address. Again, help or suggestions please.
#
# Thanks in advance for all help.
# Processing post URL: https://www.fiatforum.com/threads/starter-motor-rampage.495608/post-4647480
# Post page response status code: 200
# Title: Technical Starter Motor Rampage
# Content: I was not sure if the starter motor I was using to turn over my recently built 540cc engine was quite doing the job so thought I would rebuild one. Checked my garage shelves and I had 5 Fiat 500 Starter Motors to suit the 499cc. How can I select the best I thought so only one thing for it, pull the first four apart to see what I will find. Realised that I had picked up one 594/650 one by mistake but that indulged my nerdy side being able to compare developments as they evolved. Found a few shocking bits and some worn or missing bits which I will show later. Reading the Haynes manual added to the knowledge and interest. So two good starters assembled so far, one for my own use and one up for grabs if anyone needs one. Also it seems that no UK suppliers have the thin steel plate that fits between the starter and the gearbox bellhousing and I have a couple going spare. These seem to be one of the bits that often get left off when an engine get reassembled. I defy anybody to fit one of those rubber boots over the lever without it tearing. My advice is to cut it strategically before attempting to fit.
# Processing post URL: https://www.fiatforum.com/threads/fiat-claims-ordes-6000-for-500-within-a-few-hours-of-launch.132801/post-1398565
# Post page response status code: 200
# Title: General Fiat claims ordes 6000 for 500 within a few hours of launch
# Content: Baerius said:
#
#
#
# but no wants a KIA either
#
# Click to expand...
#
# You'd be amazed how many do!
# Scraping complete.

# %% [markdown]
# This code scrapes forum posts and comments from the Fiat 500X Owners Club website. It starts from a specific search results page and navigates through multiple pages (up to 12), extracting the title, content, comments, and timestamps from each post. The extracted data is saved into a CSV file.

# %%
import requests
from bs4 import BeautifulSoup
import csv

# Forum search results homepage URL
base_url = "https://www.500xownersclub.co.uk"
search_url = "/search/544/?q=fiat+uk&o=relevance"

# Set request headers
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

# Initial page URL
current_url = base_url + search_url

# Create a CSV file and save it to the specified path
file_path = 'E:/ARP/forum_data_12_pages.csv'
with open(file_path, mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(["Title", "Content", "Comment", "Comment Time"])

    # Limit the number of pages to scrape
    max_pages = 12
    current_page = 1

    while current_url and current_page <= max_pages:
        print(f"Processing page URL: {current_url}")
        response = requests.get(current_url, headers=headers)
        print(f"Page response status code: {response.status_code}")
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find all post links
        post_links = soup.find_all("a", href=True, qid="search-results-title")
        if not post_links:
            print("No post links found.")
            break
        
        print("Found post links:")
        for link in post_links:
            post_url = link.get('href')
            full_post_url = base_url + post_url if post_url.startswith('/') else post_url
            print(f"Processing post URL: {full_post_url}")
            post_response = requests.get(full_post_url, headers=headers)
            print(f"Post page response status code: {post_response.status_code}")
            post_soup = BeautifulSoup(post_response.text, 'html.parser')

            # Extract post title
            title_tag = post_soup.find("h1", class_="p-title-value")
            title = title_tag.get_text().strip() if title_tag else "No title"
            print(f"Title: {title}")

            # Extract post content
            content_tag = post_soup.find("div", class_="bbWrapper", itemprop="text")
            content = content_tag.get_text().strip() if content_tag else "No content"
            print(f"Content: {content}")

            # Extract comments and timestamps
            comments = post_soup.find_all("div", class_="bbWrapper", itemprop="text")
            time_tags = post_soup.find_all("time", class_="u-dt")
            for comment, time_tag in zip(comments, time_tags):
                comment_text = comment.get_text().strip()
                comment_time = time_tag.get('datetime', 'No time')
                if comment_text:
                    writer.writerow([title, content, comment_text, comment_time])

        # Find the next page link
        next_page = soup.find("a", class_="pageNav-jump pageNav-jump--next")
        if next_page:
            current_url = base_url + next_page.get('href')
            current_page += 1
        else:
            current_url = None

print("Scraping complete.")
# Out:
# Processing page URL: https://www.500xownersclub.co.uk/search/544/?q=fiat+uk&o=relevance
# Page response status code: 409
# No post links found.
# Scraping complete.
